# %% [markdown]
# # Yelp Data Challenge - Data Preprocessing
#
# BitTiger DS501
#
# Jun 2017

# %% [markdown]
# ## Dataset Introduction
#
# [Yelp Dataset Challenge](https://www.yelp.com/dataset_challenge)
#
# The Challenge Dataset:
#
#     4.1M reviews and 947K tips by 1M users for 144K businesses
#     1.1M business attributes, e.g., hours, parking availability, ambience.
#     Aggregated check-ins over time for each of the 125K businesses
#     200,000 pictures from the included businesses
#
# Cities:
#
#     U.K.: Edinburgh
#     Germany: Karlsruhe
#     Canada: Montreal and Waterloo
#     U.S.: Pittsburgh, Charlotte, Urbana-Champaign, Phoenix, Las Vegas, Madison, Cleveland
#
# Files:
#
#     yelp_academic_dataset_business.json
#     yelp_academic_dataset_checkin.json
#     yelp_academic_dataset_review.json
#     yelp_academic_dataset_tip.json
#     yelp_academic_dataset_user.json
#
# Notes on the Dataset
#
#     Each file is composed of a single object type, one json-object per-line.
#     Take a look at some examples to get you started: https://github.com/Yelp/dataset-examples.

# %% [markdown]
# ## Read data from file and load to Pandas DataFrame
#
# **Warning**: Loading all the 1.8 GB data into Pandas at a time takes long time and a lot of memory!

# %%
import json
import pandas as pd

# %%
file_business, file_checkin, file_review, file_tip, file_user = [
    'yelp_dataset_challenge_round9/yelp_academic_dataset_business.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_checkin.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_review.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_tip.json',
    'yelp_dataset_challenge_round9/yelp_academic_dataset_user.json'
]

# %% [markdown]
# #### Business Data

# %%
with open('sample_data/business.json') as f:
    df_business=pd.DataFrame(json.loads(line) for line in f)

# %%
df_business.head(2)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-6bc2132ea3e8> in <module>()
# ----> 1 df_business.head(2)
#
# NameError: name 'df_business' is not defined

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156639 entries, 0 to 156638
# Data columns (total 15 columns):
# address         156639 non-null object
# attributes      156639 non-null object
# business_id     156639 non-null object
# categories      156639 non-null object
# city            156639 non-null object
# hours           156639 non-null object
# is_open         156639 non-null int64
# latitude        156638 non-null float64
# longitude       156638 non-null float64
# name            156639 non-null object
# neighborhood    156639 non-null object
# postal_code     156639 non-null object
# review_count    156639 non-null int64
# stars           156639 non-null float64
# state           156639 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 17.9+ MB

# %% [markdown]
# #### Checkin Data

# %%
# with open(file_checkin) as f:
#     df_checkin = pd.DataFrame(json.loads(line) for line in f)
# df_checkin.head(2)

# %% [markdown]
# #### Review Data

# %%
# with open(file_review) as f:
#     df_review = pd.DataFrame(json.loads(line) for line in f)
# df_review.head(2)

# %% [markdown]
# #### Tip Data

# %%
# with open(file_tip) as f:
#     df_tip = pd.DataFrame(json.loads(line) for line in f)
# df_tip.head(2)

# %% [markdown]
# #### User Data

# %%
# with open(file_user) as f:
#     df_user = pd.DataFrame(json.loads(line) for line in f)
# df_user.head(2)

# %% [markdown]
# ## Filter data by city and category

# %% [markdown]
# #### Create filters/masks
#
# * create filters that selects business
#     * that are located in "Las Vegas"
#     * that contains "Restaurants" in their category (You may need to filter null categories first)

# %%
# Create Pandas DataFrame filters
cond_city=df_business['city'].isin (['Las Vegas' , 'LV','las vegas','LAS VEGAS','LASVEGAS','LasVegas','lv'])

# isnull bool

category_notnull=~df_business['categories'].isnull()

# first, apply(str) convert categories to strings, then check if it contains restaurants

category_resturant=df_business['categories'].apply(str).str.contains('Restaurants|restaurants|restaurant|Restaurant')

# %%
df_business[df_business['city'].isin (['Las Vegas' , 'LV','las vegas','LAS VEGAS','LASVEGAS','LasVegas','lv'])]
# Out:
#                                                   address  \
# 10                                11022 W Charleston Blvd
# 19                                     2385 E Windmill Ln
# 39                                     6162 W Flamingo Rd
# 40                                     4755 W Flamingo Rd
# 48                                  9410 W Lake Mead Blvd
# 58                                  2400 E Lake Mead Blvd
# 64                                    4190 S Rainbow Blvd
# 75                                       3827 E Sunset Rd
# 88                             3585 S Decatur Blvd, Ste C
# 90                                      6325 E Russell Rd
# 107                       1203 E Charleston Blvd, Ste 140
# 116     South Point Hotel & Casino, 9777 S Las Vegas Blvd
# 123                                 8255 Las Vegas Blvd S
# 129                                1812 E Charleston Blvd
# 133                       7200 Cathedral Rock Dr, Ste 250
# 138                                     9336 W Sahara Ave
# 140                           6040 S Rainbow Blvd, Ste B2
# 148                                      6185 Harrison Dr
# 152                       5115 Spring Mountain Rd, Ste113
# 171                                 3377 S Las Vegas Blvd
# 181                                 9165 South Jones Blvd
# 188                                        3500 Meade Ave
# 194                         10420 S Decatur Blvd, Ste 110
# 195                          2600 S Rainbow Blvd, Ste 108
# 205                       11700 W Charleston, Ste 170-488
# 206                                      3616 N Rancho Dr
# 212                              4710 W Dewey Dr, Ste 102
# 213                          5580 S Decatur Blvd, Ste 109
# 214                                    3250 W Ali Baba Ln
# 215                                 3565 Las Vegas Blvd S
# ...                                                   ...
# 156472                              3327 Las Vegas Blvd S
# 156473                              3400 Las Vegas Blvd S
# 156482                                  2488 E Russell Rd
# 156486                                  3570 N Buffalo Dr
# 156488                               910 Las Vegas Blvd S
# 156489                                       401 S 4th St
# 156490                                 800 W Mesquite Ave
# 156512                       7450 W Cheyenne Ave, Ste 114
# 156516                                    701 Bridger Ave
# 156517                                      375 Lewis Ave
# 156518                                     20 Research Ln
# 156525                               3514 E Tropicana Ave
# 156542                 The Palazzo, 3255 S Las Vegas Blvd
# 156543                     3663 Las Vegas Blvd S, Ste 490
# 156558
# 156566                          2790 E Flamingo Rd, Ste A
# 156567                              3049 S Las Vegas Blvd
# 156570
# 156572                           8755 Lindell Rd, Ste 100
# 156581                              6340 McLeod Dr, Ste 6
# 156593                               4310 E Tropicana Ave
# 156604                                3450 N Hualapai Way
# 156608           Fashion Show Mall, 3200 Las Vegas Blvd S
# 156610                              1800 Las Vegas Blvd S
# 156611                         4130 S Sandhill Rd, Ste A5
# 156615                                    5680 S Pecos Rd
# 156616                           5868 S Pecos Rd, Ste 200
# 156620                             7101 W Craig Rd, Ste 1
# 156623                         316 E Bridger Ave, Ste 101
# 156635         Star Trek The Experience, 3000 Paradise Rd
#
#                                                attributes  \
# 10      {u'BusinessAcceptsCreditCards': True, u'GoodFo...
# 19                                                     {}
# 39      {u'BusinessParking': {u'garage': False, u'stre...
# 40                  {u'BusinessAcceptsCreditCards': True}
# 48                                                     {}
# 58      {u'GoodForMeal': {u'dessert': False, u'latenig...
# 64      {u'RestaurantsPriceRange2': 1, u'RestaurantsAt...
# 75                  {u'BusinessAcceptsCreditCards': True}
# 88      {u'BusinessParking': {u'garage': False, u'stre...
# 90      {u'BusinessAcceptsCreditCards': True, u'Restau...
# 107     {u'GoodForMeal': {u'dessert': False, u'latenig...
# 116     {u'GoodForMeal': {u'dessert': False, u'latenig...
# 123                {u'BusinessAcceptsCreditCards': False}
# 129     {u'BusinessAcceptsCreditCards': True, u'Restau...
# 133     {u'AcceptsInsurance': True, u'ByAppointmentOnl...
# 138                 {u'BusinessAcceptsCreditCards': True}
# 140     {u'AcceptsInsurance': True, u'ByAppointmentOnl...
# 148     {u'BusinessAcceptsCreditCards': True, u'Restau...
# 152     {u'BusinessParking': {u'garage': True, u'stree...
# 171     {u'BusinessAcceptsCreditCards': True, u'Restau...
# 181                                                    {}
# 188                                                    {}
# 194     {u'AcceptsInsurance': True, u'ByAppointmentOnl...
# 195     {u'AcceptsInsurance': True, u'ByAppointmentOnl...
# 205     {u'BusinessAcceptsCreditCards': True, u'ByAppo...
# 206     {u'BusinessParking': {u'garage': False, u'stre...
# 212                                                    {}
# 213                 {u'BusinessAcceptsCreditCards': True}
# 214     {u'BusinessAcceptsCreditCards': True, u'Restau...
# 215     {u'BusinessAcceptsCreditCards': True, u'Busine...
# ...                                                   ...
# 156472  {u'BusinessAcceptsCreditCards': True, u'Restau...
# 156473  {u'Alcohol': u'full_bar', u'HasTV': True, u'Ou...
# 156482              {u'BusinessAcceptsCreditCards': True}
# 156486                                                 {}
# 156488  {u'Alcohol': u'full_bar', u'HasTV': True, u'No...
# 156489  {u'BusinessAcceptsCreditCards': True, u'GoodFo...
# 156490              {u'BusinessAcceptsCreditCards': True}
# 156512                       {u'ByAppointmentOnly': True}
# 156516             {u'BusinessAcceptsCreditCards': False}
# 156517  {u'GoodForMeal': {u'dessert': False, u'latenig...
# 156518  {u'Alcohol': u'none', u'BusinessAcceptsCreditC...
# 156525                                                 {}
# 156542  {u'Alcohol': u'full_bar', u'HasTV': True, u'No...
# 156543  {u'BusinessAcceptsCreditCards': True, u'Restau...
# 156558                                                 {}
# 156566  {u'RestaurantsTableService': True, u'GoodForMe...
# 156567  {u'GoodForMeal': {u'dessert': False, u'latenig...
# 156570              {u'BusinessAcceptsCreditCards': True}
# 156572  {u'BusinessAcceptsCreditCards': True, u'ByAppo...
# 156581  {u'BusinessAcceptsCreditCards': True, u'Busine...
# 156593  {u'RestaurantsGoodForGroups': True, u'Restaura...
# 156604              {u'BusinessAcceptsCreditCards': True}
# 156608  {u'BusinessAcceptsCreditCards': True, u'Restau...
# 156610  {u'GoodForMeal': {u'dessert': False, u'latenig...
# 156611  {u'BusinessParking': {u'garage': False, u'stre...
# 156615  {u'GoodForMeal': {u'dessert': False, u'latenig...
# 156623 -115.143516                 Brooks Brothers Bail Bonds       Downtown
# 156635 -115.152919                   Quark's Bar & Restaurant       Eastside
#
#        postal_code  review_count  stars state
# 10           89135            13    4.5    NV
# 19           89123             3    3.5    NV
# 39           89103            20    4.5    NV
# 40           89103            54    5.0    NV
# 48           89134             4    2.5    NV
# 58           89030            12    3.0    NV
# 64           89103             7    3.5    NV
# 75           89120            12    5.0    NV
# 88           89103            16    4.5    NV
# 90           89122            17    3.5    NV
# 107          89104           330    4.5    NV
# 116          89183           175    3.0    NV
# 123          89123             3    4.5    NV
# 129          89104             4    2.0    NV
# 133          89128             4    4.0    NV
# 138          89117            36    4.0    NV
# 140          89118           109    5.0    NV
# 148          89102            14    1.0    NV
# 152          89146             7    2.0    NV
# 171          89109             8    3.0    NV
# 181          89139             7    3.5    NV
# 188          89102             6    5.0    NV
# 194          89141            29    5.0    NV
# 195          89146             6    3.5    NV
# 205          89135             3    5.0    NV
# 206          89130            37    4.0    NV
# 212          89118             4    5.0    NV
# 213          89118            13    4.5    NV
# 214          89118             9    3.0    NV
# 215          89109            34    1.0    NV
# ...            ...           ...    ...   ...
# 156472       89109             4    4.0    NV
# 156473       89109             7    4.0    NV
# 156482       89120            10    4.0    NV
# 156486       89129             3    3.5    NV
# 156488       89101           215    3.5    NV
# 156489       89101            21    4.5    NV
# 156490       89106            17    2.5    NV
# 156512       89129             5    5.0    NV
# 156516       89101             3    3.0    NV
# 156517       89101            47    4.5    NV
# 156518       89101             3    5.0    NV
# 156525       89121             7    4.0    NV
# 156542       89109          1421    3.5    NV
# 156543       89109            13    4.0    NV
# 156558       89129            41    5.0    NV
# 156566       89121            34    4.5    NV
# 156567       89109          2185    4.0    NV
# 156570       89101             3    5.0    NV
# 156572       89139             5    3.5    NV
# 156581       89120            17    5.0    NV
# 156593       89121             6    2.0    NV
# 156604       89129             8    1.5    NV
# 156608       89109            13    2.5    NV
# 156610       89104           108    3.0    NV
# 156611       89121             3    5.0    NV
# 156615       89120             9    4.5    NV
# 156616       89120             4    5.0    NV
# 156620       89129            22    4.0    NV
# 156623       89101             5    5.0    NV
# 156635       89109            42    4.0    NV
#
# [24797 rows x 15 columns]

# %%
# Create filtered DataFrame, and name it df_filtered
df_filtered=df_business[ cond_city & category_notnull & category_resturant]
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5688 entries, 58 to 156635
# Data columns (total 15 columns):
# address         5688 non-null object
# attributes      5688 non-null object
# business_id     5688 non-null object
# categories      5688 non-null object
# city            5688 non-null object
# hours           5688 non-null object
# is_open         5688 non-null int64
# latitude        5688 non-null float64
# longitude       5688 non-null float64
# name            5688 non-null object
# neighborhood    5688 non-null object
# postal_code     5688 non-null object
# review_count    5688 non-null int64
# stars           5688 non-null float64
# state           5688 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 711.0+ KB

# %% [markdown]
# #### Keep relevant columns
#
# * only keep some useful columns
#     * business_id
#     * name
#     * categories
#     * stars

# %%
selected_features = [u'business_id', u'name', u'categories', u'stars']

# %%
# Make a DataFrame that contains only the abovementioned columns, and name it as df_selected_business
df_selected_business=df_filtered[selected_features]

# %%
# Rename the column name "stars" to "avg_stars" to avoid naming conflicts with review dataset
df_selected_business.rename(columns={'stars':'ave_stars'}, inplace=True)
# Out:
# C:\Users\Lei Lei\Anaconda2\lib\site-packages\pandas\core\frame.py:2844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
# Inspect your DataFrame
df_selected_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5688 entries, 58 to 156635
# Data columns (total 4 columns):
# business_id    5688 non-null object
# name           5688 non-null object
# categories     5688 non-null object
# ave_stars      5688 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 222.2+ KB

# %% [markdown]
# #### Save results to csv files

# %%
# Save to ./data/selected_business.csv for your next task
df_selected_business.to_csv("selected_business.csv", index=False, encoding="utf-8")

# %%
# Try reload the csv file to check if everything works fine
df_selected_business=pd.read_csv('selected_business.csv', encoding='utf-8')

# %%
df_selected_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5688 entries, 0 to 5687
# Data columns (total 4 columns):
# business_id    5688 non-null object
# name           5688 non-null object
# categories     5688 non-null object
# ave_stars      5688 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 177.8+ KB

# %% [markdown]
# ### Use the "business_id" column to filter review data
#
# * We want to make a DataFrame that contain and only contain the reviews about the business entities we just obtained

# %% [markdown]
# #### Load review dataset

# %%
with open('sample_data/review.json') as f:
    df_review = pd.DataFrame(json.loads(line) for line in f)
df_review.head(2)
# Out:
#            address                                         attributes  \
# 0  691 Richmond Rd  {u'RestaurantsPriceRange2': 2, u'BusinessParki...
# 1   2824 Milton Rd  {u'GoodForMeal': {u'dessert': False, u'latenig...
#
#               business_id                                         categories  \
# 0  YDf95gJZaq05wvo7hTQbbQ                       [Shopping, Shopping Centers]
# 1  mLwM-h2YhXl2NCgdS84_Bw  [Food, Soul Food, Convenience Stores, Restaura...
#
#                city                                              hours  \
# 0  Richmond Heights  {u'Monday': u'10:00-21:00', u'Tuesday': u'10:0...
# 1         Charlotte  {u'Monday': u'10:00-22:00', u'Tuesday': u'10:0...
#
#    is_open   latitude  longitude                                name  \
# 0        1  41.541716 -81.493116                Richmond Town Square
# 1        0  35.236870 -80.741976  South Florida Style Chicken & Ribs
#
#   neighborhood postal_code  review_count  stars state
# 0                    44143            17    2.0    OH
# 1     Eastland       28215             4    4.5    NC

# %% [markdown]
# #### Prepare dataframes to be joined, - on business_id

# %%
# Prepare the business dataframe and set index to column "business_id", and name it as df_left
df_left=df_selected_business.set_index('business_id')

# %%
df_left.head()
# Out:
#                                                    name  \
# business_id
# LDMCrFlGIFUN6L-FEFgzWg                    El Pollo Loco
# QTH_XGh4rWYdd0fTW-tUDw         Baja Fresh Mexican Grill
# DiA78qPtp6rfRNdomzjBbw  Joshan Filipino Oriental Market
# YTqtM2WFhcMZGeAGA08Cfg         Mariscos Playa Escondida
# Oto60yDwk1z72WmfWEYrjg                    Baja Miguel's
#
#                                                                categories  \
# business_id
# LDMCrFlGIFUN6L-FEFgzWg  [Restaurants, American (Traditional), Mexican,...
# QTH_XGh4rWYdd0fTW-tUDw                             [Mexican, Restaurants]
# DiA78qPtp6rfRNdomzjBbw   [Chinese, Food, Convenience Stores, Restaurants]
# YTqtM2WFhcMZGeAGA08Cfg  [Seafood, Restaurants, Specialty Food, Ethnic ...
# Oto60yDwk1z72WmfWEYrjg                       [Food, Restaurants, Mexican]
#
#                         ave_stars
# business_id
# LDMCrFlGIFUN6L-FEFgzWg        3.0
# QTH_XGh4rWYdd0fTW-tUDw        3.5
# DiA78qPtp6rfRNdomzjBbw        3.5
# YTqtM2WFhcMZGeAGA08Cfg        4.5
# Oto60yDwk1z72WmfWEYrjg        3.0

# %%
df_left.reset_index(inplace=True)

# %%
df_left.reset_index()
# Out:
#                  business_id                                    name  \
# 0     LDMCrFlGIFUN6L-FEFgzWg                           El Pollo Loco
# 1     QTH_XGh4rWYdd0fTW-tUDw                Baja Fresh Mexican Grill
# 2     DiA78qPtp6rfRNdomzjBbw         Joshan Filipino Oriental Market
# 3     YTqtM2WFhcMZGeAGA08Cfg                Mariscos Playa Escondida
# 4     Oto60yDwk1z72WmfWEYrjg                           Baja Miguel's
# 5     mUk-0jToBuzk4KaDXp-uew                     Taza Indian Kitchen
# 6     1CP8aJa8ILlfM5deroar0Q                                Wingstop
# 7     TYGVaav4hWZioQlk9Ig78A                 Cody's Smokin' Barbecue
# 8     Wbi-x-1Nbn6LFCMOSN6F5Q                                Cafe Rio
# 9     W-3Sy3fy85mQdd0ZNFKIiw                              Applebee's
# 10    rihKlAiPgJa5XcpZ1h9-bw                                     KFC
# 11    kqO-dgJ_Ww17qVJXsPTfnw                             Golden Cake
# 12    vjLgZg0DH_9xwcujFNb0pA                             BJ's Buffet
# 13    O3OH5IEFMPtz7mPKakPZ3Q                               Japaneiro
# 14    q7OKOkEK-pgAQNjDiVd4bA                                Kilroy's
# 15    y-O3h7CV6X6P5ey1ZFcQwA                           Murdock Meals
# 16    eS76100l3h7Ollb5s3_M4A                        Mad House Coffee
# 17    gSR9bmBa0HacSuMX5BIAxg   Marie Callender's Restaurant & Bakery
# 18    rN3gHTjqx5sOnoUpJ-6jyg                         Edge Steakhouse
# 19    LwQB9H3jZ9wTk24Lr-AnZQ                  Spago by Wolfgang Puck
# 20    REJPrXEZly4PDQNmiMGI8Q                      Robertos Taco Shop
# 21    YQ--LJ7pvjiDSqNv0TuKTQ                     Grimaldi's Pizzeria
# 22    4hG2j_ibsNblDgqei05U_g                            Social House
# 23    _XM07jbQGliVPwnAfyyGUA                  Yafo Kosher Restaurant
# 24    mgc8BmE6Tdt4MVOy6siZoA         Food Court at Fashion Show Mall
# 25    sPd9YmvS6eSWzTvqowcBXA                  Tropical Smoothie Cafe
# 26    JXYeMN_VyIZyrveANnIVpA                                  Subway
# 27    Ohy6TtDSeJkVAtIHXP7pMw                                  Subway
# 28    Piw03nxAXZF86UYaVrDn1g               Sbarro the Italian Eatery
# 29    nepZ1HPAgBqw0TgJWbSgOA  Sin City Smokers Barbecue and Catering
# ...                      ...                                     ...
# 5658  ElyDWPaVOhaHJOHoQv6PBw                              Bacon Boys
# 5659  UGiMMw54qYxac0eE_cBbaA               Sammy's Beach Bar & Grill
# 5660  qQXc9D6PV1Y8RhIBZpj-Jg                        Laos Asia Market
# 5661  bfY7lYQWOg1UosYbJQceAw                               Carl's Jr
# 5662  JMpATuCfHzeP-DASD7DpXQ                           Super Burrito
# 5663  LrO_Xy6lfpbTgFoJcOjY4w                       Round Table Pizza
# 5664  bK_eTLw_uEuEyMzdZlKN6A                                   Sensi
# 5665  Kbidfh24_7-a380tovQeYA          Bahía Centroamerica Restaurant
# 5666  WIvzaGdl-leuDb5TNtiNFg                          Senor Miguel's
# 5667  PxoBae2DdxirOTdwRIsb2g                             Don Tortaco
# 5668  5Zc41a446gV3K_o7CDs69Q                  Riviera Hotel & Casino
# 5669  Lau3N654yNyWdIIybea1uA                              Il Fornaio
# 5670  EneqsOFGCK4KXofNHsc5aQ                         In-N-Out Burger
# 5671  zpoZ6WyQUYff18-z4ZU1mA                            The Goodwich
# 5672  CmBnas2zg5JyigmXclc4JQ                   Mama Luigi's Pizzeria
# 5673  RGUZF7YaHiBs10ok2sAoWw                      Silver State Diner
# 5674  mEhW0TYZi1xor_Xp15Fc2w                 L & L Hawaiian Barbecue
# 5675  wJAs37fHi3iqQ8Huym1mGg                       Sports Book Grill
# 5676  dj7DPWQRYhUxApqc4jCv7w                   Suns Beef Jerky Pecos
# 5677  iwGhazq9eP51PSerTrMrwg                       Mr G's Pub & Grub
# 5678  IyrDnrvUKpndj5zIv1KvGQ           Doña Maria Tamales Restaurant
# 5679  UEuvtQTKNS0w53oJTrwS2Q                       Sin City Sandwich
# 5680  y8wucy_3sH2FGE1auFpkXQ       Golden Bar & Restaurant Equipment
# 5681  VsewHMsfj1Mgsl2i_hio7w        LAVO Italian Restaurant & Lounge
# 5682  jLTJw1Gm9Q9KG-iS2PWkpA                     American Gypsy Cafe
# 5683  RwMLuOkImBIqqYj4SSKSPg                          Tacos El Gordo
# 5684  hgwkI7cx-ki7cWOSzzyTLw                         Quickee Burgers
# 5685  HUKbH7r9TBJPri6LJbBKtw                            Tacos Mexico
# 5686  nKph91qATrPCbJ-QwZjDZw                Hand Car Wash - Sinclair
# 5687  9QtHDX71JnaQbmzWWVbi-A                Quark's Bar & Restaurant
#
#                                              categories  ave_stars
# 0     [Restaurants, American (Traditional), Mexican,...        3.0
# 1                                [Mexican, Restaurants]        3.5
# 2      [Chinese, Food, Convenience Stores, Restaurants]        3.5
# 3     [Seafood, Restaurants, Specialty Food, Ethnic ...        4.5
# 4                          [Food, Restaurants, Mexican]        3.0
# 5                      [Indian, Pakistani, Restaurants]        3.0
# 6          [Chicken Wings, American (New), Restaurants]        3.0
# 7                               [Restaurants, Barbeque]        4.5
# 8                                [Restaurants, Mexican]        2.5
# 9     [Sports Bars, Nightlife, Burgers, Bars, Americ...        2.5
# 10              [Fast Food, Chicken Wings, Restaurants]        1.5
# 11                        [Bakeries, Food, Restaurants]        2.0
# 12                               [Restaurants, Buffets]        1.5
# 13    [Tapas Bars, Restaurants, French, Asian Fusion...        4.5
# 14       [American (Traditional), Restaurants, Burgers]        3.0
# 15    [Health & Medical, Food Delivery Services, Ame...        5.0
# 16    [Bagels, Breakfast & Brunch, Restaurants, Coff...        4.0
# 17        [Bakeries, American (New), Food, Restaurants]        3.0
# 18                           [Restaurants, Steakhouses]        4.0
# 19    [American (Traditional), American (New), Resta...        4.0
# 20    [Mexican, Food, Restaurants, Specialty Food, T...        3.0
# 21                                 [Restaurants, Pizza]        4.0
# 22    [Japanese, Lounges, Bars, Nightlife, Asian Fus...        4.0
# 23                                [Kosher, Restaurants]        3.0
# 24                      [Food Court, Restaurants, Food]        2.5
# 25    [Juice Bars & Smoothies, Sandwiches, Food, Res...        3.0
# 26                 [Sandwiches, Restaurants, Fast Food]        2.5
# 27    [Sandwiches, American (Traditional), Fast Food...        3.5
# 28                               [Italian, Restaurants]        2.5
# 29    [American (Traditional), Food, Barbeque, Food ...        4.5
# ...                                                 ...        ...
# 5658  [Burgers, Food, Restaurants, Specialty Food, A...        4.5
# 5659  [Nightlife, Bars, American (New), Sports Bars,...        2.0
# 5660  [Food, Ethnic Grocery, Laotian, Grocery, Resta...        4.5
# 5661                  [Fast Food, Restaurants, Burgers]        2.5
# 5662                             [Mexican, Restaurants]        4.0
# 5663                      [Restaurants, Pizza, Buffets]        3.5
# 5664       [Asian Fusion, Nightlife, Restaurants, Bars]        4.0
# 5665  [Salvadoran, Honduran, Restaurants, Latin Amer...        4.0
# 5666                             [Restaurants, Mexican]        2.5
# 5667                  [Mexican, Fast Food, Restaurants]        2.5
# 5668  [Arts & Entertainment, Casinos, Hotels & Trave...        2.5
# 5669             [Pizza, Restaurants, Seafood, Italian]        3.5
# 5670                  [Fast Food, Burgers, Restaurants]        4.0
# 5671  [Breakfast & Brunch, Restaurants, Sandwiches, ...        4.5
# 5672                               [Pizza, Restaurants]        4.5
# 5673                     [Restaurants, Burgers, Diners]        4.5
# 5674       [Restaurants, Hawaiian, Fast Food, Barbeque]        3.0
# 5675     [Pub Food, Fast Food, Restaurants, Sandwiches]        3.5
# 5676  [Thai, Restaurants, Juice Bars & Smoothies, Sp...        4.0
# 5677  [American (Traditional), Beer, Wine & Spirits,...        4.0
# 5678  [Seafood, American (Traditional), Food, Mexica...        3.5
# 5679  [Food, Coffee & Tea, Restaurants, Event Planni...        4.5
# 5680  [Home & Garden, Discount Store, Appliances, Sh...        5.0
# 5681  [Lounges, Bars, Restaurants, Breakfast & Brunc...        3.5
# 5682  [Mediterranean, Persian/Iranian, Restaurants, ...        4.5
# 5683                      [Tacos, Mexican, Restaurants]        4.0
# 5684                  [Burgers, Restaurants, Fast Food]        2.0
# 5685                             [Restaurants, Mexican]        3.0
# 5686  [Gas Stations, Restaurants, Car Wash, Delis, F...        4.5
# 5687                      [American (New), Restaurants]        4.0
#
# [5688 rows x 4 columns]

# %%
df_left
# Out:
#                  business_id                                    name  \
# 0     LDMCrFlGIFUN6L-FEFgzWg                           El Pollo Loco
# 1     QTH_XGh4rWYdd0fTW-tUDw                Baja Fresh Mexican Grill
# 2     DiA78qPtp6rfRNdomzjBbw         Joshan Filipino Oriental Market
# 3     YTqtM2WFhcMZGeAGA08Cfg                Mariscos Playa Escondida
# 4     Oto60yDwk1z72WmfWEYrjg                           Baja Miguel's
# 5     mUk-0jToBuzk4KaDXp-uew                     Taza Indian Kitchen
# 6     1CP8aJa8ILlfM5deroar0Q                                Wingstop
# 7     TYGVaav4hWZioQlk9Ig78A                 Cody's Smokin' Barbecue
# 8     Wbi-x-1Nbn6LFCMOSN6F5Q                                Cafe Rio
# 9     W-3Sy3fy85mQdd0ZNFKIiw                              Applebee's
# 10    rihKlAiPgJa5XcpZ1h9-bw                                     KFC
# 11    kqO-dgJ_Ww17qVJXsPTfnw                             Golden Cake
# 12    vjLgZg0DH_9xwcujFNb0pA                             BJ's Buffet
# 13    O3OH5IEFMPtz7mPKakPZ3Q                               Japaneiro
# 14    q7OKOkEK-pgAQNjDiVd4bA                                Kilroy's
# 15    y-O3h7CV6X6P5ey1ZFcQwA                           Murdock Meals
# 16    eS76100l3h7Ollb5s3_M4A                        Mad House Coffee
# 17    gSR9bmBa0HacSuMX5BIAxg   Marie Callender's Restaurant & Bakery
# 18    rN3gHTjqx5sOnoUpJ-6jyg                         Edge Steakhouse
# 19    LwQB9H3jZ9wTk24Lr-AnZQ                  Spago by Wolfgang Puck
# 20    REJPrXEZly4PDQNmiMGI8Q                      Robertos Taco Shop
# 21    YQ--LJ7pvjiDSqNv0TuKTQ                     Grimaldi's Pizzeria
# 22    4hG2j_ibsNblDgqei05U_g                            Social House
# 23    _XM07jbQGliVPwnAfyyGUA                  Yafo Kosher Restaurant
# 24    mgc8BmE6Tdt4MVOy6siZoA         Food Court at Fashion Show Mall
# 25    sPd9YmvS6eSWzTvqowcBXA                  Tropical Smoothie Cafe
# 26    JXYeMN_VyIZyrveANnIVpA                                  Subway
# 27    Ohy6TtDSeJkVAtIHXP7pMw                                  Subway
# 28    Piw03nxAXZF86UYaVrDn1g               Sbarro the Italian Eatery
# 29    nepZ1HPAgBqw0TgJWbSgOA  Sin City Smokers Barbecue and Catering
# ...                      ...                                     ...
# 5658  ElyDWPaVOhaHJOHoQv6PBw                              Bacon Boys
# 5659  UGiMMw54qYxac0eE_cBbaA               Sammy's Beach Bar & Grill
# 5660  qQXc9D6PV1Y8RhIBZpj-Jg                        Laos Asia Market
# 5661  bfY7lYQWOg1UosYbJQceAw                               Carl's Jr
# 5662  JMpATuCfHzeP-DASD7DpXQ                           Super Burrito
# 5663  LrO_Xy6lfpbTgFoJcOjY4w                       Round Table Pizza
# 5664  bK_eTLw_uEuEyMzdZlKN6A                                   Sensi
# 5665  Kbidfh24_7-a380tovQeYA          Bahía Centroamerica Restaurant
# 5666  WIvzaGdl-leuDb5TNtiNFg                          Senor Miguel's
# 5667  PxoBae2DdxirOTdwRIsb2g                             Don Tortaco
# 5668  5Zc41a446gV3K_o7CDs69Q                  Riviera Hotel & Casino
# 5669  Lau3N654yNyWdIIybea1uA                              Il Fornaio
# 5670  EneqsOFGCK4KXofNHsc5aQ                         In-N-Out Burger
# 5671  zpoZ6WyQUYff18-z4ZU1mA                            The Goodwich
# 5672  CmBnas2zg5JyigmXclc4JQ                   Mama Luigi's Pizzeria
# 5673  RGUZF7YaHiBs10ok2sAoWw                      Silver State Diner
# 5674  mEhW0TYZi1xor_Xp15Fc2w                 L & L Hawaiian Barbecue
# 5675  wJAs37fHi3iqQ8Huym1mGg                       Sports Book Grill
# 5676  dj7DPWQRYhUxApqc4jCv7w                   Suns Beef Jerky Pecos
# 5677  iwGhazq9eP51PSerTrMrwg                       Mr G's Pub & Grub
# 5678  IyrDnrvUKpndj5zIv1KvGQ           Doña Maria Tamales Restaurant
# 5679  UEuvtQTKNS0w53oJTrwS2Q                       Sin City Sandwich
# 5680  y8wucy_3sH2FGE1auFpkXQ       Golden Bar & Restaurant Equipment
# 5681  VsewHMsfj1Mgsl2i_hio7w        LAVO Italian Restaurant & Lounge
# 5682  jLTJw1Gm9Q9KG-iS2PWkpA                     American Gypsy Cafe
# 5683  RwMLuOkImBIqqYj4SSKSPg                          Tacos El Gordo
# 5684  hgwkI7cx-ki7cWOSzzyTLw                         Quickee Burgers
# 5685  HUKbH7r9TBJPri6LJbBKtw                            Tacos Mexico
# 5686  nKph91qATrPCbJ-QwZjDZw                Hand Car Wash - Sinclair
# 5687  9QtHDX71JnaQbmzWWVbi-A                Quark's Bar & Restaurant
#
#                                              categories  ave_stars
# 0     [Restaurants, American (Traditional), Mexican,...        3.0
# 1                                [Mexican, Restaurants]        3.5
# 2      [Chinese, Food, Convenience Stores, Restaurants]        3.5
# 3     [Seafood, Restaurants, Specialty Food, Ethnic ...        4.5
# 4                          [Food, Restaurants, Mexican]        3.0
# 5                      [Indian, Pakistani, Restaurants]        3.0
# 6          [Chicken Wings, American (New), Restaurants]        3.0
# 7                               [Restaurants, Barbeque]        4.5
# 8                                [Restaurants, Mexican]        2.5
# 9     [Sports Bars, Nightlife, Burgers, Bars, Americ...        2.5
# 10              [Fast Food, Chicken Wings, Restaurants]        1.5
# 11                        [Bakeries, Food, Restaurants]        2.0
# 12                               [Restaurants, Buffets]        1.5
# 13    [Tapas Bars, Restaurants, French, Asian Fusion...        4.5
# 14       [American (Traditional), Restaurants, Burgers]        3.0
# 15    [Health & Medical, Food Delivery Services, Ame...        5.0
# 16    [Bagels, Breakfast & Brunch, Restaurants, Coff...        4.0
# 17        [Bakeries, American (New), Food, Restaurants]        3.0
# 18                           [Restaurants, Steakhouses]        4.0
# 19    [American (Traditional), American (New), Resta...        4.0
# 20    [Mexican, Food, Restaurants, Specialty Food, T...        3.0
# 21                                 [Restaurants, Pizza]        4.0
# 22    [Japanese, Lounges, Bars, Nightlife, Asian Fus...        4.0
# 23                                [Kosher, Restaurants]        3.0
# 24                      [Food Court, Restaurants, Food]        2.5
# 25    [Juice Bars & Smoothies, Sandwiches, Food, Res...        3.0
# 26                 [Sandwiches, Restaurants, Fast Food]        2.5
# 27    [Sandwiches, American (Traditional), Fast Food...        3.5
# 28                               [Italian, Restaurants]        2.5
# 29    [American (Traditional), Food, Barbeque, Food ...        4.5
# ...                                                 ...        ...
# 5658  [Burgers, Food, Restaurants, Specialty Food, A...        4.5
# 5659  [Nightlife, Bars, American (New), Sports Bars,...        2.0
# 5660  [Food, Ethnic Grocery, Laotian, Grocery, Resta...        4.5
# 5661                  [Fast Food, Restaurants, Burgers]        2.5
# 5662                             [Mexican, Restaurants]        4.0
# 5663                      [Restaurants, Pizza, Buffets]        3.5
# 5664       [Asian Fusion, Nightlife, Restaurants, Bars]        4.0
# 5665  [Salvadoran, Honduran, Restaurants, Latin Amer...        4.0
# 5666                             [Restaurants, Mexican]        2.5
# 5667                  [Mexican, Fast Food, Restaurants]        2.5
# 5668  [Arts & Entertainment, Casinos, Hotels & Trave...        2.5
# 5669             [Pizza, Restaurants, Seafood, Italian]        3.5
# 5670                  [Fast Food, Burgers, Restaurants]        4.0
# 5671  [Breakfast & Brunch, Restaurants, Sandwiches, ...        4.5
# 5672                               [Pizza, Restaurants]        4.5
# 5673                     [Restaurants, Burgers, Diners]        4.5
# 5674       [Restaurants, Hawaiian, Fast Food, Barbeque]        3.0
# 5675     [Pub Food, Fast Food, Restaurants, Sandwiches]        3.5
# 5676  [Thai, Restaurants, Juice Bars & Smoothies, Sp...        4.0
# 5677  [American (Traditional), Beer, Wine & Spirits,...        4.0
# 5678  [Seafood, American (Traditional), Food, Mexica...        3.5
# 5679  [Food, Coffee & Tea, Restaurants, Event Planni...        4.5
# 5680  [Home & Garden, Discount Store, Appliances, Sh...        5.0
# 5681  [Lounges, Bars, Restaurants, Breakfast & Brunc...        3.5
# 5682  [Mediterranean, Persian/Iranian, Restaurants, ...        4.5
# 5683                      [Tacos, Mexican, Restaurants]        4.0
# 5684                  [Burgers, Restaurants, Fast Food]        2.0
# 5685                             [Restaurants, Mexican]        3.0
# 5686  [Gas Stations, Restaurants, Car Wash, Delis, F...        4.5
# 5687                      [American (New), Restaurants]        4.0
#
# [5688 rows x 4 columns]

# %%
# Prepare the review dataframe and set index to column "business_id", and name it as df_right
df_right=df_review.set_index('business_id')

# %% [markdown]
# #### Join! and reset index

# %%
# Join df_left and df_right. What type of join?
df_joined=df_left.join(df_right,how='inner')

# %%
# use merge method

df_joined=pd.merge(df_left, df_right, how='inner',on='business_id')

# %%
# You may want to reset the index 
df_joined.reset_index(inplace=True)

# %% [markdown]
# #### We further filter data by date, e.g. keep comments from last 2 years
#
# * Otherwise your laptop may crush on memory when running machine learning algorithms
# * Purposefully ignoring the reviews made too long time ago

# %%
# Make a filter that selects date after 2015-01-20
cond_last_2_years=df_joined['date']>u'2015-01-20'

# %%
# Filter the joined DataFrame and name it as df_final
df_final=df_joined[cond_last_2_years]

# %% [markdown]
# #### Take a glance at the final dataset
#
# * Do more EDA here as you like!

# %%
import matplotlib.pyplot as plt

% matplotlib inline

# %%
# e.g. calculate counts of reviews per business entity, and plot it
df_final['business_id'].value_counts().plot.hist(bins=100)

# %% [markdown]
# ## Save your preprocessed dataset to csv file
#
# * Respect your laptop's hard work! You don't want to make it run everything again.

# %%
# Save to ./data/last_2_years_restaurant_reviews.csv for your next task
df_final.to_csv('data_preprocessing/last_2_year_restaurants_reviews.csv', index=False, encoding='utf-8')
